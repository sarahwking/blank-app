# %% [markdown]
# <a href="https://colab.research.google.com/github/sarahwking/blank-app/blob/main/cardiovascular_death_rate_vs_gdp_per_capita.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0825aa6f-007f-4cb5-ac30-804f31a70cda" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0825aa6f-007f-4cb5-ac30-804f31a70cda">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('cardiovascular-death-rate-vs-gdp-per-capita.csv')
df.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  2000
# 1  Afghanistan  AFG  2001
# 2  Afghanistan  AFG  2002
# 3  Afghanistan  AFG  2003
# 4  Afghanistan  AFG  2004
#
#    Age-standardized death rate from cardiovascular diseases among both sexes  \
# 0                                          696.05510
# 1                                          702.28590
# 2                                          692.65076
# 3                                          681.37740
# 4                                          675.17290
#
#    GDP per capita, PPP (constant 2021 international $)  \
# 0                                          1617.8264
# 1                                          1454.1108
# 2                                          1774.3087
# 3                                          1815.9282
# 4                                          1776.9182
#
#    Population (historical) World Bank's income classification
# 0               20130334.0               Low-income countries
# ...

# %%
fig = px.bar(df,
             x="Entity",
             y="Age-standardized death rate from cardiovascular diseases among both sexes",
             color="World Bank's income classification",
             title="Cardiovascular Disease Death Rates by Country and Income Classification")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
